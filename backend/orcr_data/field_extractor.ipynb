# %%
import pandas as pd

# %%
df=pd.read_csv('ORCR_16_22_all.csv')
df
# Out:
#        Unnamed: 0                                   Institute  \
# 0               0  Indian Institute of Technology Bhubaneswar
# 1               1  Indian Institute of Technology Bhubaneswar
# 2               2  Indian Institute of Technology Bhubaneswar
# 3               3  Indian Institute of Technology Bhubaneswar
# 4               4  Indian Institute of Technology Bhubaneswar
# ...           ...                                         ...
# 89431       89431      Indian Institute of Technology Dharwad
# 89432       89432      Indian Institute of Technology Dharwad
# 89433       89433      Indian Institute of Technology Dharwad
# 89434       89434      Indian Institute of Technology Dharwad
# 89435       89435      Indian Institute of Technology Dharwad
#
#                                    Academic Program Name Quota Seat Type  \
# 0      Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# ...

# %%
institutes=df["Institute"].unique()
branches=df["Academic Program Name"].unique()
quota=df["Quota"].unique()
seat=df["Seat Type"].unique()
gender=df["Gender"].unique()
orank=df["Opening Rank"].unique()
crank=df["Closing Rank"].unique()
year=df["Year"].unique()
round=df["Round"].unique()

# %%
print(seat)
# Out:
# ['OPEN' 'OBC-NCL' 'SC' 'ST' 'OPEN (PwD)' 'OBC-NCL (PwD)' 'SC (PwD)'
#  'ST (PwD)' 'EWS' 'EWS (PwD)']

# %%
with open('allbranch.txt','w') as file:
    file.write('\n'.join(branches))
with open('allinstitutes.txt','w') as file:
    file.write('\n'.join(institutes))

with open('allseat.txt','w') as file:
    file.write('\n'.join(seat))
# with open('allor.txt','w') as file:
#     file.write('\n'.join(orank))
# with open('allcr.txt','w') as file:
#     file.write('\n'.join(crank))

with open('allquota.txt','w') as file:
    for qt in quota:
        file.write(str(qt)+'\n')
with open('allyear.txt','w') as file:
    for yr in year:
        file.write(str(yr)+'\n')

with open('allround.txt','w') as file:
    for rnd in round:
        file.write(str(rnd)+'\n')

with open('allgender.txt','w') as file:
    for gen in gender:
        file.write(str(gen)+'\n')
